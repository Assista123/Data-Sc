# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # Chiemerie Chinedu
# Data Scientist

# %% [markdown]
# _I am interested in data science because of it's ability to take raw, unfiltered and seeming random data and transform it to valuable insight that could take productivity to the next level_

# %% [markdown]
# ### My code in the next cell "print(1+1)" will output the result of adding 1 to 1

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# Below is a horizontal rule
# ___
#
# Below is a bullet list
# + IBM Knowledge Catalog
# + IBM Watson Studio
#
# This is ~~Strikethrough~~
